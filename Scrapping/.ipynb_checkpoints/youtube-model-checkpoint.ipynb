# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
df = pd.read_csv('data_all_info.csv')
df.head()

# %%
#df.drop(df.columns[[0,1,5,6,7,9]], axis=1, inplace=True)
# Out:
# {       'etag': 'si7ksIXGBjMzXwvLcsGN15jv36A',
#         'items': [       {       'etag': 'WeN33tdkBW1rXiWXYBX0t_WTouA',
#                                  'id': 'UgwiNeL_zWW6hwJK2dd4AaABAg',
#                                  'kind': 'youtube#commentThread',
#                                  'snippet': {       'canReply': True,
#                                                     'isPublic': True,
#                                                     'topLevelComment': {       'etag': 'EMDa3QRTzze3812t3L2tixtLj_o',
#                                                                                'id': 'UgwiNeL_zWW6hwJK2dd4AaABAg',
#                                                                                'kind': 'youtube#comment',
#                                                                                'snippet': {       'authorChannelId': {       'value': 'UCBNhSnObzjEze4tJk2DyBNQ'},
# ...

# %%
df.count()
df.isnull().sum(axis = 0) #columns
null_rows = len(df[df.isna().any(axis=1)]) #rows
print(f'Rows with NaNs: {null_rows} ({(null_rows/df.shape[0])*100:.0f}%)')

# %%
#df.fillna('', inplace=True)
#df.head()

# %%
df[['','']] = df[['','']].applymap(lambda x: ' '.join(x.replace(' ', '').split(',')[:3]))
df.head()

# %%
titles_corpus = df[''].apply(' '.join, axis=1)
